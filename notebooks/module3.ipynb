# %%
import sys
print(sys.version)
import tensorflow as tf
print("tensorflow", tf.__version__)
# Out:
# 3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]
# tensorflow 2.21.0

# %%
import os
os.chdir("..")            # move up from notebooks/ to module3/
print("now in:", os.getcwd())
# Out:
# now in: c:\Users\asus\Downloads\Module 3\module3_scaffold\module3

# %%
print(os.listdir("data/raw"))
# Out:
# ['fraudTest.csv', 'fraudTrain.csv', 'README.txt']

# %%
import sys, os
sys.path.append(os.getcwd())
from src.config import load_config, path
from src.features.phase1_features import build_dataset
from src.models.phase2_model import train_model, _run

cfg = load_config()
train = build_dataset(path(cfg["data"]["train_csv"]), nrows=cfg["data"]["nrows"])
model, hist, _ = train_model(train, cfg)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 9
#       5 from src.models.phase2_model import train_model, _run
#       6
#       7 cfg = load_config()
#       8 train = build_dataset(path(cfg["data"]["train_csv"]), nrows=cfg["data"]["nrows"])
# ----> 9 _run()
#
# File c:\Users\asus\Downloads\Module 3\module3_scaffold\module3\src\models\phase2_model.py:80, in _run()
#      78 nrows = cfg["data"]["nrows"]
#      79 train = build_dataset(path(cfg["data"]["train_csv"]), nrows=nrows)
# ---> 80 m, hist, _ = train_model(train, cfg, bidirectional=cfg["model"]["bidirectional"])
#      81 m.save(path("results/models/module3_model.keras"))
#      83 try:
#      84      # type: ignore[import-not-found]
#
# KeyError: 'bidirectional'
